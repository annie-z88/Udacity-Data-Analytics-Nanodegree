# %% [markdown]
# # Project: TMDb Movies Data Analysis
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# >  In this project, we will be analyzing a data set of over 10,000 movie titles to explore patterns within the data. This data set was taken from The Movie Database (TMDb). Each row corresponds to a movie title and inclues relevant data about each movie.
#    * The following variables will be included in our analysis:
#            - popularity
#            - revenue
#            - director
#            - voute count
#            - revenue adj
#            - release year
#    * The two questions we will be exploring are:
#           1) Can we provide a list of the top 10 most popular directors based on ratings of high revenue movies?
#           2) How is popularity of high revenue movies trending over time?

# %%
# Use this cell to set up import statements for all of the packages that you
#   plan to use.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Remember to include a 'magic word' so that your visualizations are plotted
#   inline with the notebook. See this page for more:
#   http://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
#
# ### General Properties

# %%
df= pd.read_csv('movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
#view dimensions of the dataset
df.shape
# Out:
# (10866, 21)

# %%
#list column names
list(df.columns)
# Out:
# ['id',
#  'imdb_id',
#  'popularity',
#  'budget',
#  'revenue',
#  'original_title',
#  'cast',
#  'homepage',
#  'director',
#  'tagline',
#  'keywords',
#  'overview',
#  'runtime',
#  'genres',
#  'production_companies',
#  'release_date',
#  'vote_count',
#  'vote_average',
#  'release_year',
#  'budget_adj',
#  'revenue_adj']

# %% [markdown]
# ### Data Cleaning - to get rid of rows with missing data

# %% [markdown]
# To drop rows where at least one element is missing -

# %%
df=df.dropna();

# %% [markdown]
# To get # of rows & columns in the dataframe -

# %%
df.shape
# Out:
# (1992, 21)

# %% [markdown]
# Drop rows where 0 (invalid) is listed as a column value for revenue & the # of rows and columns as a result -

# %%
df_revenue=df.query('revenue != 0')
df_revenue.shape
# Out:
# (1446, 21)

# %%
#to convert column names to string
df_revenue.columns = df.columns.astype(str)

# %%
#summary of revenue data
df_revenue.describe().revenue_adj
# Out:
# count    1.446000e+03
# mean     1.794165e+08
# std      2.859650e+08
# min      1.000000e+01
# 25%      1.665450e+07
# 50%      7.098536e+07
# 75%      2.123399e+08
# max      2.827124e+09
# Name: revenue_adj, dtype: float64

# %% [markdown]
# Filter for revenues greater than the mean to find high revenue movie titles --

# %%
df_toprevenue=df.query('revenue_adj >= 1.794165e+08')
df_toprevenue
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10689     660  tt0059800    1.910465   11000000   141195658
# 10724     668  tt0064757    1.778746    7000000    81974493
# 10759     948  tt0077651    1.198849     300000    70000000
# 10760    8469  tt0077975    1.157930    2700000   141000000
# 10819   16214  tt0077696    0.044675          0    78000000
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...                                ...
# 10689                      Thunderball
# 10724  On Her Majesty's Secret Service
# 10759                        Halloween
# 10760                     Animal House
# 10819                           Hooper
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10689  Sean Connery|Claudine Auger|Adolfo Celi|Lucian...
# 10724  George Lazenby|Diana Rigg|Telly Savalas|Gabrie...
# 10759  Donald Pleasence|Jamie Lee Curtis|P.J. Soles|N...
# 10760  John Belushi|Tim Matheson|John Vernon|Verna Bl...
# 10819  Burt Reynolds|Robert Klein|Adam West|Jan-Micha...
#
#                                                 homepage          director  \
# 0                          http://www.jurassicworld.com/   Colin Trevorrow
# 1                            http://www.madmaxmovie.com/     George Miller
# 2         http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3      http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                               http://www.furious7.com/         James Wan
# ...                                                  ...               ...
# 10689    http://www.mgm.com/view/movie/2009/Thunderball/     Terence Young
# 10724  http://www.mgm.com/view/movie/1411/On-Her-Maje...     Peter R. Hunt
# 10759  http://www.theofficialjohncarpenter.com/hallow...    John Carpenter
# 10760                        http://www.animalhouse.com/       John Landis
# 10819         http://en.wikipedia.org/wiki/Hooper_(film)       Hal Needham
#
#                                                  tagline  ...  \
# 0                                      The park is open.  ...
# 1                                     What a Lovely Day.  ...
# 2                             One Choice Can Destroy You  ...
# 3                          Every generation has a story.  ...
# 4                                    Vengeance Hits Home  ...
# ...                                                  ...  ...
# 10689                    Look up!  Look down!  Look out!  ...
# 10724  Far up! Far out! Far more! James Bond 007 is b...  ...
# 10759                            The Night HE Came Home!  ...
# 10760  It was the Deltas against the rules... the rul...  ...
# 10819                       The greatest stuntman alive!  ...
#
#                                                 overview runtime  \
# 0      Twenty-two years after the events of Jurassic ...     124
# 1      An apocalyptic story set in the furthest reach...     120
# 2      Beatrice Prior must confront her inner demons ...     119
# 3      Thirty years after defeating the Galactic Empi...     136
# 4      Deckard Shaw seeks revenge against Dominic Tor...     137
# ...                                                  ...     ...
# 10689  A criminal organization has obtained two nucle...     130
# 10724  James Bond tracks archnemesis Ernst Blofeld to...     142
# 10759  A psychotic murderer, institutionalized since ...      91
# 10760  At a 1962 College, Dean Vernon Wormer is deter...     109
# 10819  Burt Reynolds plays a legendary stunt man know...     107
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10689                  Adventure|Action|Thriller
# 10724                  Adventure|Action|Thriller
# 10759                            Horror|Thriller
# 10760                                     Comedy
# 10819                              Action|Comedy
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...       6/9/15
# 1      Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15
# 2      Summit Entertainment|Mandeville Films|Red Wago...      3/18/15
# 3              Lucasfilm|Truenorth Productions|Bad Robot     12/15/15
# 4      Universal Pictures|Original Film|Media Rights ...       4/1/15
# ...                                                  ...          ...
# 10689          Eon Productions|Metro-Goldwyn-Mayer (MGM)     12/16/65
# 10724   Eon Productions|Metro-Goldwyn-Mayer (MGM)|Danjaq     12/12/69
# 10759  Compass International Pictures|Falcon Internat...     10/25/78
# 10760  Universal Pictures|Oregon Film Factory|Stage I...      7/27/78
# 10819                                       Warner Bros.      7/28/78
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0           5562           6.5          2015  1.379999e+08  1.392446e+09
# 1           6185           7.1          2015  1.379999e+08  3.481613e+08
# 2           2480           6.3          2015  1.012000e+08  2.716190e+08
# 3           5292           7.5          2015  1.839999e+08  1.902723e+09
# 4           2947           7.3          2015  1.747999e+08  1.385749e+09
# ...          ...           ...           ...           ...           ...
# 10689        331           6.3          1965  7.612620e+07  9.771535e+08
# 10724        258           6.4          1969  4.160985e+07  4.872780e+08
# 10759        522           7.3          1978  1.002810e+06  2.339890e+08
# 10760        230           6.7          1978  9.025292e+06  4.713208e+08
# 10819         13           6.0          1978  0.000000e+00  2.607307e+08
#
# [413 rows x 21 columns]

# %%
#drop rows where 0 is listed as a column value for popularity
df_popularity=df_toprevenue.query('popularity != 0')

# %%
df_popularity.shape
#There are 413 movie titles we can use to analyze popularity data after dropping null/zero value rows.
# Out:
# (413, 21)

# %%
#summary of popularity data
df_popularity.describe().popularity
#data is right skewed because the mean/average is higher than the median
# Out:
# count    413.000000
# mean       3.203209
# std        3.116262
# min        0.044675
# 25%        1.592578
# 50%        2.411533
# 75%        3.791881
# max       32.985763
# Name: popularity, dtype: float64

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
#
# ### Research Question 1: Can we provide a list of the top 10 most popular directors based on ratings of high revenue movies?

# %%
#filter for popularity scores greater than the mean
df_highpopularity=df_popularity.query('popularity > 3.203209')
df_highpopularity.drop(['id','imdb_id','cast','homepage'],axis=1,inplace=True)
df_highpopularity
# Out:
#       popularity     budget     revenue                      original_title  \
# 0      32.985763  150000000  1513528810                      Jurassic World
# 1      28.419936  150000000   378436354                  Mad Max: Fury Road
# 2      13.112507  110000000   295238201                           Insurgent
# 3      11.173104  200000000  2068178225        Star Wars: The Force Awakens
# 4       9.335014  190000000  1506249360                           Furious 7
# ...          ...        ...         ...                                 ...
# 8243    3.966538   28000000   504050219                             Aladdin
# 8375    4.578300   18000000   389925971             Raiders of the Lost Ark
# 8458    3.293387   80000000   457696359                 Mission: Impossible
# 9180    3.536655   48000000   474171806  Indiana Jones and the Last Crusade
# 9316    3.852269   25000000   377350553                Beauty and the Beast
#
#                       director  \
# 0              Colin Trevorrow
# 1                George Miller
# 2             Robert Schwentke
# 3                  J.J. Abrams
# 4                    James Wan
# ...                        ...
# 8243  Ron Clements|John Musker
# 8375          Steven Spielberg
# 8458            Brian De Palma
# 9180          Steven Spielberg
# 9316  Gary Trousdale|Kirk Wise
#
#                                                 tagline  \
# 0                                     The park is open.
# 1                                    What a Lovely Day.
# 2                            One Choice Can Destroy You
# 3                         Every generation has a story.
# 4                                   Vengeance Hits Home
# ...                                                 ...
# 8243                                      Wish granted!
# 8375  Indiana Jones - the new hero from the creators...
# 8458                             Expect the Impossible.
# 9180  The man with the hat is back. And this time, h...
# 9316           The most beautiful love story ever told.
#
#                                                keywords  \
# 0     monster|dna|tyrannosaurus rex|velociraptor|island
# 1      future|chase|post-apocalyptic|dystopia|australia
# 2     based on novel|revolution|dystopia|sequel|dyst...
# 3                 android|spaceship|jedi|space opera|3d
# 4                   car race|speed|revenge|suspense|car
# ...                                                 ...
# 8243                magic|musical|cartoon|princess|love
# 8375       saving the world|riddle|nepal|himalaya|cairo
# 8458         paris|london|cia|terrorist|secret identity
# 9180  saving the world|venice|holy grail|library|riddle
# 9316                    prince|book|castle|rose|musical
#
#                                                overview  runtime  \
# 0     Twenty-two years after the events of Jurassic ...      124
# 1     An apocalyptic story set in the furthest reach...      120
# 2     Beatrice Prior must confront her inner demons ...      119
# 3     Thirty years after defeating the Galactic Empi...      136
# 4     Deckard Shaw seeks revenge against Dominic Tor...      137
# ...                                                 ...      ...
# 8243  Princess Jasmine grows tired of being forced t...       90
# 8375  When Dr. Indiana Jones â€“ the tweed-suited pr...      115
# 8458  When Ethan Hunt, the leader of a crack espiona...      110
# 9180  When Dr. Henry Jones Sr. suddenly goes missing...      127
# 9316  Follow the adventures of Belle, a bright young...       84
#
#                                          genres  \
# 0     Action|Adventure|Science Fiction|Thriller
# 1     Action|Adventure|Science Fiction|Thriller
# 2            Adventure|Science Fiction|Thriller
# 3      Action|Adventure|Science Fiction|Fantasy
# 4                         Action|Crime|Thriller
# ...                                         ...
# 8243  Animation|Family|Comedy|Adventure|Fantasy
# 8375                           Adventure|Action
# 8458                  Adventure|Action|Thriller
# 9180                           Adventure|Action
# 9316     Romance|Family|Animation|Fantasy|Music
#
#                                    production_companies release_date  \
# 0     Universal Studios|Amblin Entertainment|Legenda...       6/9/15
# 1     Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15
# 2     Summit Entertainment|Mandeville Films|Red Wago...      3/18/15
# 3             Lucasfilm|Truenorth Productions|Bad Robot     12/15/15
# 4     Universal Pictures|Original Film|Media Rights ...       4/1/15
# ...                                                 ...          ...
# 8243                               Walt Disney Pictures     11/25/92
# 8375                       Lucasfilm|Paramount Pictures      6/12/81
# 8458       Paramount Pictures|Cruise/Wagner Productions      5/21/96
# 9180                       Lucasfilm|Paramount Pictures      5/24/89
# 9316  Walt Disney Pictures|Walt Disney Animation Stu...     11/12/91
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0           5562           6.5          2015  1.379999e+08  1.392446e+09
# 1           6185           7.1          2015  1.379999e+08  3.481613e+08
# 2           2480           6.3          2015  1.012000e+08  2.716190e+08
# 3           5292           7.5          2015  1.839999e+08  1.902723e+09
# 4           2947           7.3          2015  1.747999e+08  1.385749e+09
# ...          ...           ...           ...           ...           ...
# 8243        2121           7.3          1992  4.351268e+07  7.833063e+08
# 8375        2506           7.5          1981  4.316743e+07  9.351169e+08
# 8458        1754           6.5          1996  1.112173e+08  6.362971e+08
# 9180        2031           7.4          1989  8.443128e+07  8.340611e+08
# 9316        1703           7.3          1991  4.002732e+07  6.041733e+08
#
# [131 rows x 17 columns]

# %%
df_highpopularity.describe()
# Out:
#        popularity        budget       revenue     runtime   vote_count  \
# count  131.000000  1.310000e+02  1.310000e+02  131.000000   131.000000
# mean     6.091292  1.284592e+08  6.594914e+08  127.511450  3639.282443
# std      4.156677  7.338596e+07  3.985204e+08   24.357076  1614.667664
# min      3.204295  6.000000e+06  1.049318e+08   81.000000  1087.000000
# 25%      3.936202  7.200000e+07  3.778935e+08  112.000000  2587.500000
# 50%      4.946136  1.300000e+08  5.435140e+08  126.000000  3382.000000
# 75%      6.187207  1.765000e+08  8.591673e+08  143.000000  4224.000000
# max     32.985763  3.800000e+08  2.781506e+09  201.000000  9767.000000
#
#        vote_average  release_year    budget_adj   revenue_adj
# count    131.000000    131.000000  1.310000e+02  1.310000e+02
# mean       7.052672   2008.091603  1.292926e+08  7.186312e+08
# std        0.651310      9.063409  6.835783e+07  4.617434e+08
# min        5.300000   1972.000000  1.216843e+07  1.899037e+08
# 25%        6.500000   2005.500000  7.362783e+07  3.934498e+08
# 50%        7.100000   2012.000000  1.298003e+08  6.067687e+08
# 75%        7.600000   2014.000000  1.679852e+08  9.600996e+08
# max        8.300000   2015.000000  3.683713e+08  2.827124e+09

# %%
df_highpopularity.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#            director                        tagline  \
# 0   Colin Trevorrow              The park is open.
# 1     George Miller             What a Lovely Day.
# 2  Robert Schwentke     One Choice Can Destroy You
# 3       J.J. Abrams  Every generation has a story.
# 4         James Wan            Vengeance Hits Home
#
#                                             keywords  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island
# 1   future|chase|post-apocalyptic|dystopia|australia
# 2  based on novel|revolution|dystopia|sequel|dyst...
# 3              android|spaceship|jedi|space opera|3d
# 4                car race|speed|revenge|suspense|car
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09

# %% [markdown]
# To get a list of directors for each movie title and the associated mean popularity.

# %%
directors=df_highpopularity.groupby('director').mean().popularity
directors
# Out:
# director
# Alan Taylor                       6.883129
# Alejandro GonzÃ¡lez IÃ±Ã¡rritu    9.110700
# Alfonso CuarÃ³n                   5.242753
# Andrew Stanton                    5.678119
# Andrew Stanton|Lee Unkrich        3.440519
#                                     ...
# Sylvester Stallone                3.748840
# Tim Burton                        5.572950
# Tony Gilroy                       4.611854
# Wes Ball                          5.553082
# Zack Snyder                       3.972460
# Name: popularity, Length: 93, dtype: float64

# %% [markdown]
# To generate a dataframe with rows and columns for the director & popularity rating-

# %%
directors_df=directors.to_frame()
directors_df
# Out:
#                                 popularity
# director
# Alan Taylor                       6.883129
# Alejandro GonzÃ¡lez IÃ±Ã¡rritu    9.110700
# Alfonso CuarÃ³n                   5.242753
# Andrew Stanton                    5.678119
# Andrew Stanton|Lee Unkrich        3.440519
# ...                                    ...
# Sylvester Stallone                3.748840
# Tim Burton                        5.572950
# Tony Gilroy                       4.611854
# Wes Ball                          5.553082
# Zack Snyder                       3.972460
#
# [93 rows x 1 columns]

# %% [markdown]
# The top 10 most popular movie directors are shown based on average popularity ratings.

# %%
directors_df.nlargest(10, ['popularity'])
# Out:
#                                 popularity
# director
# Colin Trevorrow                  32.985763
# George Miller                    28.419936
# James Gunn                       14.311205
# Robert Schwentke                 13.112507
# Joe Russo|Anthony Russo          12.971027
# J.J. Abrams                      11.173104
# Christopher Nolan                10.954310
# Alejandro GonzÃ¡lez IÃ±Ã¡rritu    9.110700
# Don Hall|Chris Williams           8.691294
# Morten Tyldum                     8.110711

# %% [markdown]
# ### Research Question 2:  How is popularity of high revenue movies trending over time?

# %%
df_trend= df_popularity.sort_values('release_year',ascending=True)
df_trend.head()
# Out:
#         id    imdb_id  popularity    budget    revenue         original_title  \
# 9849   646  tt0055928    3.170651   1100000   59600000                 Dr. No
# 10438  657  tt0057076    2.508235   2500000   78898765  From Russia With Love
# 9881   658  tt0058150    3.153791   3500000  124900000             Goldfinger
# 10689  660  tt0059800    1.910465  11000000  141195658            Thunderball
# 10401  667  tt0062512    1.554808   9500000  111584787    You Only Live Twice
#
#                                                     cast  \
# 9849   Sean Connery|Ursula Andress|Joseph Wiseman|Jac...
# 10438  Sean Connery|Daniela Bianchi|Lotte Lenya|Rober...
# 9881   Sean Connery|Honor Blackman|Gert FrÃ¶be|Shirle...
# 10689  Sean Connery|Claudine Auger|Adolfo Celi|Lucian...
# 10401  Sean Connery|Akiko Wakabayashi|Karin Dor|Mie H...
#
#                                                 homepage       director  \
# 9849           http://www.mgm.com/view/movie/566/Dr.-No/  Terence Young
# 10438  http://www.mgm.com/view/movie/717/From-Russia-...  Terence Young
# 9881       http://www.mgm.com/view/movie/760/Goldfinger/   Guy Hamilton
# 10689    http://www.mgm.com/view/movie/2009/Thunderball/  Terence Young
# 10401  http://www.mgm.com/view/movie/2347/You-Only-Li...  Lewis Gilbert
#
#                                                  tagline  ...  \
# 9849   NOW meet the most extraordinary gentleman spy ...  ...
# 10438  The world's masters of murder pull out all the...  ...
# 9881        Everything he touches turns into excitement!  ...
# 10689                    Look up!  Look down!  Look out!  ...
# 10401  You Only Live Twice...and Twice is the only wa...  ...
#
#                                                 overview runtime  \
# 9849   In the film that launched the James Bond saga,...     110
# 10438  Agent 007 is back in the second installment of...     115
# 9881   Special agent 007 (Sean Connery) comes face to...     110
# 10689  A criminal organization has obtained two nucle...     130
# 10401  A mysterious space craft kidnaps a Russian and...     117
#
#                           genres  \
# 9849   Adventure|Action|Thriller
# 10438  Action|Thriller|Adventure
# 9881   Adventure|Action|Thriller
# 10689  Adventure|Action|Thriller
# 10401  Action|Thriller|Adventure
#
#                                    production_companies release_date  \
# 9849          Eon Productions|Metro-Goldwyn-Mayer (MGM)      10/4/62
# 10438  Eon Productions|Metro-Goldwyn-Mayer (MGM)|Danjaq     10/11/63
# 9881          Eon Productions|Metro-Goldwyn-Mayer (MGM)      9/17/64
# 10689         Eon Productions|Metro-Goldwyn-Mayer (MGM)     12/16/65
# 10401                                   Eon Productions      6/12/67
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 9849         560           6.7          1962  7.929294e+06  4.296236e+08
# 10438        458           6.7          1963  1.780045e+07  5.617734e+08
# 9881         602           7.0          1964  2.460594e+07  8.780804e+08
# 10689        331           6.3          1965  7.612620e+07  9.771535e+08
# 10401        301           6.2          1967  6.209926e+07  7.294034e+08
#
# [5 rows x 21 columns]

# %% [markdown]
# Correlation matrix to view relationships between variables of the df_trend dataset

# %%
df_trend.shape
corr_matrix = df_trend.corr()
plt.figure(figsize=(10,10))
heat_map = sns.heatmap(corr_matrix, annot=True)
bottom, top = heat_map.get_ylim()
heat_map.set_ylim(bottom + 0.5, top - 0.5);

# %% [markdown]
# Isolating the popularity and release year columns to analyze popularity trends over time.

# %%
df_poptrend=df_trend[['popularity', 'release_year']]
df_poptrend
# Out:
#        popularity  release_year
# 9849     3.170651          1962
# 10438    2.508235          1963
# 9881     3.153791          1964
# 10689    1.910465          1965
# 10401    1.554808          1967
# ...           ...           ...
# 91       1.904898          2015
# 95       1.841779          2015
# 129      1.291013          2015
# 19       5.476958          2015
# 0       32.985763          2015
#
# [413 rows x 2 columns]

# %%
df_poptrend.plot(title="Popularity Trends Over Time",x="release_year",y="popularity",kind="scatter", c="coral");

# %% [markdown]
# To find average popularity of each release year of high revenue movies

# %%
from numpy.polynomial.polynomial import polyfit

# %%
b, m=polyfit(df_poptrend.release_year,df_poptrend.popularity, 1)
best_fit_y=(m*df_poptrend.release_year)+b

# %% [markdown]
# To view best fit line better, y limit was set to 15 on the graph to block out outliers. The red dashed line represents the best fit line for the dataset.

# %%
plt.title('Popularity Trends Over Time')
plt.xlabel('Release Year')
plt.ylabel('Popularity')
plt.ylim(top=15)
plt.scatter(df_poptrend.release_year,df_poptrend.popularity,c='green')
plt.plot(df_poptrend.release_year,best_fit_y,'--',color='red');

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# ### Results:
# The data suggests the following:
#     1. There is not a significant correlation between popularity and revenue.
#     2. There was more data to base off of due to higher amount of popularity ratings over time.
#     3. There is not big correlation between runtime of movies and budget.
#     4. There is, however, a higher correlation between budget and revenue.
#
# ### Limitations:
# A few limitations exist within the data:
#     1. Some correlations provided in the correlation matrix are limited due to differing variable types.
#     2. There is not a lot of data from previous years prior to the 2000s to draw a more accurate conclusion from regarding popularity trends over time.
